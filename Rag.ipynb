# %% [markdown]
# #Install Dependencies

# %%
import os
from google.colab import userdata

# Set up your git config details
os.environ["GITHUB_USERNAME"] = "aayushks2003"
os.environ["GITHUB_EMAIL"] = "06719011621.aiml@gmail.com"
os.environ["GITHUB_TOKEN"] = userdata.get('GITHUB_TOKEN')

# Apply the global config to git
# !git config --global user.name $GITHUB_USERNAME
# !git config --global user.email $GITHUB_EMAIL

print("Git profile configuration complete and secure!")

# REPO_NAME = "RAG on youtube transcript" # Name of your repo on GitHub

# # 1. Initialize a local git repository
# !git init

# # # 2. Add your files
# # !git add README.md
# # !git add transcript.txt
# !git add Rag.ipynb # or !git add app.py

# 3. Commit your changes
# !git commit -m "Initial commit from Google Colab"

# 4. Rename default branch to main
# !git branch -M main

# 5. Connect to GitHub using your secret token authenticated URL
repo_url = f"https://{os.environ['GITHUB_USERNAME']}:{os.environ['GITHUB_TOKEN']}@github.com/{os.environ['GITHUB_USERNAME']}/{REPO_NAME}.git"
# !git remote add origin {repo_url}


# 6. Push it!
# !git push -u origin main
# Out:
# Git profile configuration complete and secure!

# %%
# 1. Initialize a local git repository
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# 1. Clear any previous conflicting git locks if they exist
# !rm -f .git/index.lock

# 2. Copy the files from Drive into your local workspace
# !cp "/content/drive/MyDrive/transcript/Rag.ipynb" ./Rag.ipynb
# !cp "/content/drive/MyDrive/transcript/transcript.txt" ./transcript.txt

# 3. Stage the files explicitly
# !git add Rag.ipynb transcript.txt

# 4. Check the status to verify they turn GREEN (staged)
# !git status
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   Rag.ipynb
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	drive/
# 	sample_data/

# %%
import os

# 1. Force add everything in the local folder to be absolutely sure transcript.txt is included
# !git add

# 2. Commit your staged files
# !git commit -m "Initial commit of secure RAG pipeline notebook and dataset"

# 3. Ensure your branch is set to main
# !git branch -M main

# 4. Set up your repository name (Ensure this matches your empty GitHub repo name perfectly)
REPO_NAME = "RAG-on-youtube-transcript"

# 5. Build your authenticated URL securely using your Colab Secrets
repo_url = f"https://{os.environ['GITHUB_USERNAME']}:{os.environ['GITHUB_TOKEN']}@github.com/{os.environ['GITHUB_USERNAME']}/{REPO_NAME}.git"

# 6. Wipe out any broken or duplicate remote configurations from earlier
# !git remote remove origin 2>/dev/null

# 7. Add your fresh origin link (Using the $ symbol so bash reads the Python variable)
# !git remote add origin $repo_url

# 8. Push your code!
# !git push -u origin main
# Out:
# ...
# error: open("drive/MyDrive/Classroom/AIML B1- G1/Aayush Kumar Singh - Programming for Problem Solving (Mid-term exam).gdoc"): Operation not supported
# error: unable to index file 'drive/MyDrive/Classroom/AIML B1- G1/Aayush Kumar Singh - Programming for Problem Solving (Mid-term exam).gdoc'
# fatal: adding files failed
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	drive/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)
# To https://github.com/aayushks2003/RAG-on-youtube-transcript.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/aayushks2003/RAG-on-youtube-transcript.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# ...

# %%
# !pip install -q langchain langchain-core langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
# !pip install -q chromadb streamlit huggingface-hub transformers langchain-huggingface
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 98.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -q langchain-openai faiss-cpu tiktoken python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 73.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"]=userdata.get('OPENAI_API_KEY')

# %% [markdown]
# #Indexing

# %% [markdown]
# ###Ingestion

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('/content/drive/MyDrive/transcript/transcript.txt', encoding='utf-8')
document = loader.load()
type(document)
# Out:
# list

# %% [markdown]
# ###Text Splitting

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=60)
chunk = splitter.split_documents(document)
chunk[99]
# Out:
# Document(metadata={'source': '/content/drive/MyDrive/trnscrpt/trnscript.txt'}, page_content="39:2739 minutes, 27 secondslet's also just remove this bit for now so we can just see what the strictured llm outputs directly and let's\n39:3639 minutes, 36 secondssee okay so now you can see that we actually have that paragraph object right the one we defined up here which is kind of cool and then in there we\n39:4539 minutes, 45 secondshave the original paragraph right so this is where this is coming from I definitely remember writing something")

# %% [markdown]
# ###Embedding

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# ###Vector Storage

# %%
from langchain_community.vectorstores import FAISS

vectorStore = FAISS.from_documents(chunk, embeddings)

# %% [markdown]
# ###Retriver

# %%
retriever = vectorStore.as_retriever(search_type="similarity", search_kwarg={"k":4})

context2 = retriever.invoke("What is this about")

context2[0].page_content
# Out:
# "21:2721 minutes, 27 secondsgoing to be using line chain to generate various sces that we might um find helpful as we're you know we have this\n21:3421 minutes, 34 secondsarticle draft and we're editing it and just kind of like finalizing it so what are those going to be you can see them here we have the title for the article\n21:4321 minutes, 43 secondsthe description and SEO friendly description specifically third one we're going to be getting the LM to Providers"

# %% [markdown]
# #Augumentation/Generation

# %% [markdown]
# ###Prompts

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    template="""
    You are an helpful AI assistant.
    Use the {context} to answer the {question}. Give the answer in understandable english.
    If the context is insufficient, just say that you don't know.
    """,
    input_variables=["context", "question"]
)

# %% [markdown]
# ###LLM Model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model = "gpt-5.4-mini-2026-03-17",
    temperature = 0.3
)

# %% [markdown]
# ###String Outparser

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %% [markdown]
# #Chains / Runnables output

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough


generator_chain = prompt | model | output_parser

retrieval_chain= RunnableParallel({
    "context":retriever,
    "question":RunnablePassthrough()
    })

main_chain = retrieval_chain | generator_chain

result=main_chain.invoke("What is this about")

result

# generator_chain.invoke({
#     "context": "this is a basic rag model",
#     "question": "why is my rag passing the retrived output as it is?"
#     })
# Out:
# 'This appears to be a transcript from a course or tutorial about **LangChain** and related tools for building AI applications.\n\nFrom the snippets, it looks like the content covers:\n- **Getting started with LangChain**\n- Building simple **LLM-powered assistants**\n- Generating things like **text, images, and structured outputs**\n- Using LangChain to help with **editing an article draft**, such as creating titles, descriptions, and SEO-friendly descriptions\n- Later chapters move into **LangSmith**, which is used for **AI observability** and tracking/debugging applications\n\nSo, in simple English: **it’s about learning how to use LangChain to build AI apps and then using LangSmith to observe and improve them.**'

# %% [markdown]
# Input

# %%
# from streamlit_chat import message

# if prompt:
#     with st.chat_message("user"):
#         st.markdown(prompt)


# from stremlit.runtime.uploaded_file_manager import UploadedFile

# input = UploadedFile()

# import streamlit as st

# if 'generated' not in st.session_state:
#     st.session_state['generated'] = []

# if 'past' not in st.session_state:
#     st.session_state['past'] = []
# messages = [
#     {"role": "system", "content": "You are a helpful assistant."}
# ]

import streamlit as st

# This box will automatically stick to the bottom of your screen
if prompt := st.chat_input("Ask your tutor a question..."):
    # Display user message in chat message container
    with st.chat_message("user"):
        st.markdown(prompt)

    # This is where your Socratic logic or RAG search would trigger
    with st.chat_message("assistant"):
        st.write("That's an interesting question! What have you tried so far?")

# %% [markdown]
# Output
